# %%
import numpy as np
import pandas as pd
import pymc3 as pm
import daft
# Out:
# ...................Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
model = pm.Model();
total_ball = 15
no_of_red_ball = 6
no_of_green_ball = 4
no_of_blue_ball = 5

with model:
    red_ball = pm.Geometric('red_ball',p=.40)
    green_ball = pm.Geometric('green_ball',p=.27)
    blue_ball = pm.Geometric('blue_ball',p=.33)
    
 
    trace = pm.sample(100000,tune=50000,progressbar = True)
# Out:
# Assigned Metropolis to red_ball
# Assigned Metropolis to green_ball
# Assigned Metropolis to blue_ball
# 100%|████████████████████████████████| 150000/150000 [00:42<00:00, 3492.03it/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CE2FAC8>,
# ...
#       dtype=object)

# %%
pm.summary(trace)
# Out:
# red_ball:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   2.507            1.957            0.020            [1.000, 6.000]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   1.000          1.000          2.000          3.000          8.000
#
#
# green_ball:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   3.674            3.123            0.034            [1.000, 10.000]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   1.000          1.000          3.000          5.000          12.000
#
#
# blue_ball:
#
# ...
